# %% [markdown]
# # Calculate thermal generator parameters

# %%
import os
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import tqdm.notebook as tqdm

import nygrid.gen_params as gp

# %%
# Set up directories
cwd = os.getcwd()
if 'examples' in cwd:
    parent_dir = os.path.dirname(cwd)
    data_dir = os.path.join(parent_dir, 'data')
else:
    data_dir = os.path.join(cwd, 'data')

grid_data_dir = os.path.join(data_dir, 'grid', '2018Baseline')
if not os.path.exists(grid_data_dir):
    raise FileNotFoundError('Grid data directory not found.')

thermal_data_dir = os.path.join(data_dir, 'thermal')
if not os.path.exists(thermal_data_dir):
    raise FileNotFoundError('Thermal data directory not found.')

print('Grid data directory: {}'.format(grid_data_dir))
print('Thermal data directory: {}'.format(thermal_data_dir))
# Out:
# Grid data directory: /mnt/Bo_HDD/NYgrid-python/data/grid/2018Baseline
# Thermal data directory: /mnt/Bo_HDD/NYgrid-python/data/thermal

# %% [markdown]
# # 1. 2018 data

# %% [markdown]
# ## Read EPA CEMS historical generation and emissions data

# %%
cems_data_dir = os.path.join(thermal_data_dir, 'cems_2018')
df_list = list()
for mo in range(1, 13):
    df = pd.read_csv(os.path.join(cems_data_dir, f'2018ny{str(mo).zfill(2)}.csv'),
                     low_memory=False)
    df_list.append(df)

# Concatenate all the dataframes
cems_df = pd.concat(df_list, axis=0, ignore_index=True)

# Rename columns
cems_df = cems_df.rename(columns={
    'ORISPL_CODE': 'Plant_ID',
    'UNITID': 'Unit_ID',
})

# Add time columns from OP_DATE and OP_HOUR
cems_df['Time'] = pd.to_datetime(
    cems_df['OP_DATE']) + pd.to_timedelta(cems_df['OP_HOUR'], unit='h')
# cems_df['Month'] = cems_df['Time'].dt.month

# Drop columns that are not needed
cems_df = cems_df.drop(columns=['STATE', 'FAC_ID', 'UNIT_ID', 'OP_DATE', 'OP_HOUR',
                                'SO2_MASS_MEASURE_FLG', 'SO2_RATE_MEASURE_FLG',
                                'NOX_MASS_MEASURE_FLG', 'NOX_RATE_MEASURE_FLG',
                                'CO2_MASS_MEASURE_FLG', 'CO2_RATE_MEASURE_FLG',
                                'SLOAD (1000lb/hr)'])

# %% [markdown]
# ## Read NYCA and CEMS generator matching table

# %%
gen_combiner = pd.read_excel(os.path.join(thermal_data_dir, '2018_nyca_thermal.xlsx'),
                             sheet_name='matched_with_id_filtered')
gen_combiner = gen_combiner.rename(columns={
    '   Station        Unit': 'NYISO_Name',
})

# Map unit type GT, JE to CT
gen_combiner['Unit Type'] = gen_combiner['Unit Type'].replace(
    {'GT': 'CT', 'JE': 'CT'})
gen_combiner['Fuel Type Secondary'] = gen_combiner['Fuel Type Secondary'].astype(
    str).replace({'nan': ''})
gen_combiner
# Out:
#            NYISO_Name Zone    PTID  Name Plate Rating (MW) Dual Fuel  \
# 0        Danskammer 1    G   23586                    72.0       YES
# 1        Danskammer 2    G   23589                    73.5       YES
# 2        Danskammer 3    G   23590                   147.1       NaN
# 3        Danskammer 4    G   23591                   239.4       NaN
# 4    Arthur Kill ST 2    J   23512                   376.2       NaN
# ..                ...  ...     ...                     ...       ...
# 217      Astoria CC 1    J  323568                   288.0       YES
# 218      Astoria CC 2    J  323569                   288.0       YES
# 219    Caithness_CC_1    K  323624                   375.0       YES
# 220       EMPIRE_CC_1    F  323656                   335.0       YES
# 221       EMPIRE_CC_2    F  323658                   335.0       YES
#
#     Unit Type Fuel Type Primary Fuel Type Secondary  2017 Net Energy (GWh)  \
# 0          ST                NG                 FO6                0.93040
# 1          ST                NG                 FO6                0.90830
# 2          ST                NG                                    2.06448
# 3          ST                NG                                    5.05390
# 4          ST                NG                                  563.62800
# ..        ...               ...                 ...                    ...
# 217        CC                NG                 FO2             2242.28930
# 218        CC                NG                 FO2                    NaN
# 219        CC                NG                 FO2             2415.15818
# 220        CC                NG                 FO2             1214.94600
# 221        CC                NG                 FO2             1142.36500
#
#        Note  ...                   CAMD_Facility_Name CAMD_Plant_ID  \
# 0       NaN  ...        Danskammer Generating Station          2480
# 1       NaN  ...        Danskammer Generating Station          2480
# 2       NaN  ...        Danskammer Generating Station          2480
# 3       NaN  ...        Danskammer Generating Station          2480
# 4       NaN  ...                          Arthur Kill          2490
# ..      ...  ...                                  ...           ...
# 217   ( G )  ...                    Poletti 500 MW CC         56196
# 218     NaN  ...                    Poletti 500 MW CC         56196
# 219     NaN  ...  Caithness Long Island Energy Center         56234
# 220     NaN  ...            Empire Generating Co, LLC         56259
# 221     NaN  ...            Empire Generating Co, LLC         56259
#
#      CAMD_Unit_ID CAMD_Generator_ID CAMD_Nameplate_Capacity  \
# 0               1                 1                    72.0
# 1               2                 2                    73.5
# 2               3                 3                   147.1
# 3               4                 4                   239.4
# 4              20                 2                   376.2
# ..            ...               ...                     ...
# 217         CTG7A              CA01                   358.0
# 218         CTG7B              CA01                   358.0
# 219          0001              CT01                   348.9
# 220          CT-1              CT11                   333.0
# 221          CT-2              CT12                   333.0
#
#            CAMD_Fuel_Type EIA_Latitude  EIA_Longitude             ID  \
# 0    Pipeline Natural Gas    41.571247     -73.974981       (2480,1)
# 1    Pipeline Natural Gas    41.571247     -73.974981       (2480,2)
# 2    Pipeline Natural Gas    41.571247     -73.974981       (2480,3)
# 3    Pipeline Natural Gas    41.571247     -73.974981       (2480,4)
# 4    Pipeline Natural Gas    40.591564     -74.200035      (2490,20)
# ..                    ...          ...            ...            ...
# 217  Pipeline Natural Gas    40.788900     -73.906900  (56196,CTG7A)
# 218  Pipeline Natural Gas    40.788900     -73.906900  (56196,CTG7B)
# 219  Pipeline Natural Gas    40.814200     -72.940300   (56234,0001)
# 220  Pipeline Natural Gas    42.625239     -73.750021   (56259,CT-1)
# 221  Pipeline Natural Gas    42.625239     -73.750021   (56259,CT-2)
#
#     eco_min_ratio_obs
# 0                0.24
# 1                0.22
# 2                0.36
# 3                0.28
# 4                0.26
# ..                ...
# 217              0.40
# 218              0.40
# 219              0.60
# 220              0.48
# 221              0.48
#
# [222 rows x 21 columns]

# %% [markdown]
# ## Calculate generator parameters based on data in 2018

# %%
os.makedirs('figures/time_series', exist_ok=True)
os.makedirs('figures/heat_rate', exist_ok=True)
os.makedirs('figures/nox_rate', exist_ok=True)
os.makedirs('figures/co2_rate', exist_ok=True)
os.makedirs('figures/so2_rate', exist_ok=True)

gen_params = dict()

for ii in tqdm.tqdm(range(gen_combiner.shape[0])):
# for ii in tqdm.tqdm(range(1)):
    gen_info = gen_combiner.iloc[ii]

    if gen_info['ID'] not in gen_params:

        gen_params[gen_info['ID']] = dict()

        unit_df = cems_df[(cems_df['Plant_ID'] == gen_info['CAMD_Plant_ID'])
                          & (cems_df['Unit_ID'] == gen_info['CAMD_Unit_ID'])]
        unit_df = unit_df.set_index('Time').sort_index()
        # print(f'Number of rows: {unit_df.shape[0]}')

        # Calculate hourly ramp
        unit_df['RAMP (MW/hour)'] = unit_df['GLOAD (MW)'].diff()

        # Filter out rows with zero values
        unit_df_nonzero = unit_df[(unit_df['HEAT_INPUT (mmBtu)'] > 0) & (
            unit_df['GLOAD (MW)'] > 0)]
        unit_df_nonzero = unit_df_nonzero.drop(columns=['FACILITY_NAME',
                                                        'Plant_ID', 'Unit_ID'])
        # print(f'Number of rows with nonzero values: {unit_df_nonzero.shape[0]}')

        if unit_df_nonzero.shape[0] > 0:

            fig_name_sfx = '_'.join([gen_info["ID"], gen_info["NYISO_Name"],
                                     gen_info["PTID"].astype(str),
                                     gen_info["Unit Type"], gen_info["Fuel Type Primary"],
                                     gen_info["Fuel Type Secondary"]])

            # Time series plot
            df_plot = unit_df[['OP_TIME', 'GLOAD (MW)', 'SO2_MASS (lbs)', 'NOX_MASS (lbs)',
                               'CO2_MASS (tons)', 'HEAT_INPUT (mmBtu)']]
            fig_ts, ax_ts = plt.subplots(6, 1, figsize=(8, 6), sharex=True,
                                   layout='constrained')
            for i in range(6):
                ax_ts[i].plot(df_plot.iloc[:, i])
                ax_ts[i].set_title(df_plot.columns[i])

            fig_ts.suptitle(fig_name_sfx)
            fig_ts.savefig(f'figures/time_series/time_series_{fig_name_sfx}.png')

            # Calculate maximum generation
            max_gen =  unit_df_nonzero['GLOAD (MW)'].max()
            
            # Calculate ramp rate
            raise_rr_ratio = (unit_df_nonzero['RAMP (MW/hour)'].max() / max_gen)
            lower_rr_ratio = np.abs(unit_df_nonzero['RAMP (MW/hour)'].min() / max_gen)
            raise_rr_ratio = raise_rr_ratio if raise_rr_ratio <= 1 else 1
            lower_rr_ratio = lower_rr_ratio if lower_rr_ratio <= 1 else 1
            
            gen_params[gen_info['ID']]['NYISO_Name'] = gen_info['NYISO_Name']
            gen_params[gen_info['ID']]['PTID'] = gen_info['PTID']
            gen_params[gen_info['ID']]['Unit_Type'] = gen_info['Unit Type']
            gen_params[gen_info['ID']]['Fuel_Type_Primary'] = gen_info['Fuel Type Primary']
            gen_params[gen_info['ID']]['Fuel_Type_Secondary'] = gen_info['Fuel Type Secondary']
            gen_params[gen_info['ID']]['CAMD_Facility_Name'] = gen_info['CAMD_Facility_Name']
            gen_params[gen_info['ID']]['CAMD_Plant_ID'] = gen_info['CAMD_Plant_ID']
            gen_params[gen_info['ID']]['CAMD_Unit_ID'] = gen_info['CAMD_Unit_ID']
            gen_params[gen_info['ID']]['CAMD_Nameplate_Capacity'] = gen_info['CAMD_Nameplate_Capacity']
            gen_params[gen_info['ID']]['raise_rr_ratio'] = raise_rr_ratio
            gen_params[gen_info['ID']]['lower_rr_ratio'] = lower_rr_ratio

            # Specific treatments for certain units
            if gen_info['ID'] == '(50978,A)':
                unit_df_nonzero = unit_df_nonzero[unit_df_nonzero['GLOAD (MW)'] < 45]
            if gen_info['ID'] == '(50292,GT1)':
                unit_df_nonzero = unit_df_nonzero[unit_df_nonzero['GLOAD (MW)'] < 50]
            if gen_info['ID'] == '(50292,GT1)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] > 20)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] < 100))]
            if gen_info['ID'] == '(50292,GT2)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] > 20)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] < 100))]
            if gen_info['ID'] == '(7146,UGT013)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] < 45)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] > 600))]
            if gen_info['ID'] == '(7146,UGT014)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] < 18)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] > 250))]            
            if gen_info['ID'] == '(7869,UGT011)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] > 10)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] < 150))]
            if gen_info['ID'] == '(2500,CT0010)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] > 20)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] < 200))]
            if gen_info['ID'] == '(2500,CT0010)':
                unit_df_nonzero = unit_df_nonzero[~((unit_df_nonzero['GLOAD (MW)'] < 20)
                                                    &(unit_df_nonzero['HEAT_INPUT (mmBtu)'] > 190))]                  

            # Heat rate plot
            heat_1, heat_0, heat_r2, eco_min, gen_sum, heat_sum, fig_heat, ax_heat = \
                gp.calc_heat_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='GLOAD (MW)',
                               y_name='HEAT_INPUT (mmBtu)',
                               calc_eco_min=False,
                               nonneg_intercept=True,
                               keep_in_range=False)
            gen_params[gen_info['ID']]['max_gen'] = max_gen
            gen_params[gen_info['ID']]['eco_min'] = eco_min
            gen_params[gen_info['ID']]['eco_min_ratio'] = eco_min / max_gen
            gen_params[gen_info['ID']]['gen_sum'] = gen_sum
            gen_params[gen_info['ID']]['heat_sum'] = heat_sum
            gen_params[gen_info['ID']]['heat_1'] = heat_1
            gen_params[gen_info['ID']]['heat_0'] = heat_0
            gen_params[gen_info['ID']]['heat_r2'] = heat_r2
            if fig_heat is not None:
                fig_heat.savefig(f'figures/heat_rate/heat_rate_{fig_name_sfx}.png')

            # NOx emission rate plot
            nox_1, nox_0, nox_r2, nox_avg_rate, nox_sum, fig_nox, ax_nox = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='HEAT_INPUT (mmBtu)',
                               y_name='NOX_MASS (lbs)',
                               rate_name='NOX_RATE (lbs/mmBtu)')
            gen_params[gen_info['ID']]['nox_1'] = nox_1
            gen_params[gen_info['ID']]['nox_0'] = nox_0
            gen_params[gen_info['ID']]['nox_r2'] = nox_r2
            gen_params[gen_info['ID']]['nox_sum'] = nox_sum
            if fig_nox is not None:
                fig_nox.savefig(f'figures/nox_rate/nox_rate_{fig_name_sfx}.png')

            # CO2 emission rate plot
            co2_1, co2_0, co2_r2, co2_avg_rate, co2_sum, fig_co2, ax_co2 = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='HEAT_INPUT (mmBtu)',
                               y_name='CO2_MASS (tons)',
                               rate_name='CO2_RATE (tons/mmBtu)')
            gen_params[gen_info['ID']]['co2_1'] = co2_1
            gen_params[gen_info['ID']]['co2_0'] = co2_0
            gen_params[gen_info['ID']]['co2_r2'] = co2_r2
            gen_params[gen_info['ID']]['co2_sum'] = co2_sum
            if fig_co2 is not None:
                fig_co2.savefig(f'figures/co2_rate/co2_rate_{fig_name_sfx}.png')

            # SO2 emission rate plot
            so2_1, so2_0, so2_r2, so2_avg_rate, so2_sum, fig_so2, ax_so2 = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='HEAT_INPUT (mmBtu)',
                               y_name='SO2_MASS (lbs)',
                               rate_name='SO2_RATE (lbs/mmBtu)')
            gen_params[gen_info['ID']]['so2_1'] = so2_1
            gen_params[gen_info['ID']]['so2_0'] = so2_0
            gen_params[gen_info['ID']]['so2_r2'] = so2_r2
            gen_params[gen_info['ID']]['so2_sum'] = so2_sum
            if fig_so2 is not None:
                fig_so2.savefig(f'figures/so2_rate/so2_rate_{fig_name_sfx}.png')

            plt.close('all')

        else:
            print(f'No data for {fig_name_sfx}.')
            gen_params[gen_info['ID']] = None

    else:
        print(f'Data for {gen_info["ID"]} already processed.')
# Out:
#   0%|          | 0/222 [00:00<?, ?it/s]
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Arthur Kill GT 1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Arthur Kill GT 1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 1-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 1-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 2-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 2-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 3-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 3-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Gowanus 4-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Gowanus 4-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Hudson Ave 3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Hudson Ave 3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Hudson Ave 5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Hudson Ave 5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 1-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 1-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-3 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-4 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-5 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-5 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-6 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-6 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-7 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-7 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Narrows 2-8 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Narrows 2-8 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 9.04 outside the range for Ravenswood ST 02
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Ravenswood 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Ravenswood 10 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Ravenswood 11 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for 59 St.  GT 1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: 59 St.  GT 1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for 74 St.  GT 1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: 74 St.  GT 1 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for 74 St.  GT 2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: 74 St.  GT 2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett GT 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett GT 02 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett 03 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett 04 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett 05 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett 06 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Barrett 08 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: East Hampton GT 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 23.20 outside the range for Northport GT
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Northport GT HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 9.52 outside the range for Port Jefferson 3
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 9.24 outside the range for Port Jefferson 4
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 25.04 outside the range for Port Jefferson GT 01
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Port Jefferson GT 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Shoreham 2 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 19.60 outside the range for Glenwood GT 01
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Glenwood GT 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:101: UserWarning: Heat rate 9.24 outside the range for Roseton 1
#   warn(f'Heat rate {slope:.2f} outside the range for {gen_info["NYISO_Name"]}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 01 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:171: UserWarning: Astoria GT 01 HEAT_INPUT (mmBtu) All data is NaN
#   warn(f'{gen_info["NYISO_Name"]} {x_name} All data is NaN', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 3-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 3-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 3-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 3-4 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 4-1 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 4-2 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)
# /mnt/Bo_HDD/NYgrid-python/dev/gen_params.py:89: UserWarning: Bad fit for Astoria GT 4-3 GLOAD (MW) HEAT_INPUT (mmBtu)
#   warn(f'Bad fit for {gen_info["NYISO_Name"]} {x_name} {y_name}', UserWarning)

# %%
# Convert the dictionary to a dataframe
gen_params_df = pd.DataFrame(gen_params).T
gen_params_df.index.name = 'ID'

# Ramp rate ratio: replace 0 with 1
gen_params_df['raise_rr_ratio'] = gen_params_df['raise_rr_ratio'].replace({0: 1})
gen_params_df['lower_rr_ratio'] = gen_params_df['lower_rr_ratio'].replace({0: 1})

# Treatment for bad fit in Astoria GT units
for i, row, in gen_params_df[gen_params_df['CAMD_Plant_ID']==55243].iterrows():
    default_heat_1 = gp.HEAT_RATE_DEFAULT[row['Unit_Type']][row['Fuel_Type_Primary']]
    row['heat_1'] = default_heat_1
    row['heat_0'] = 0
    row['heat_r2'] = 0
    gen_params_df.loc[i] = row

# Treatment fo bad fit in Bethpage CC units
for i, row, in gen_params_df[(gen_params_df['CAMD_Plant_ID']==50292) & (gen_params_df['Unit_Type']=='CC')].iterrows():
    default_heat_1 = gp.HEAT_RATE_DEFAULT[row['Unit_Type']][row['Fuel_Type_Primary']]
    row['heat_1'] = default_heat_1
    row['heat_0'] = 0
    row['heat_r2'] = 0
    gen_params_df.loc[i] = row

# %%
# Save to excel
gen_params_df.to_excel(os.path.join(thermal_data_dir, 'gen_params_2018.xlsx'))

# %% [markdown]
# # 2. 2024 data

# %% [markdown]
# ## Process additional generator data

# %%
cems_data_dir_2 = os.path.join(thermal_data_dir, 'cems_additional_data')
file_list = [
    'Bayonne Energy Center_56964_2023.csv', # Unit 9 and 10 are not in 2018
    'Linden Cogeneration Facility_50006_2023.csv',
    'Valley Energy Center_56940_2023.csv', # Not in 2018
    'Cricket Valley Energy Center_57185_2023.csv' # Not in 2018
]

df_list_2 = list()
for file in file_list:
    df = pd.read_csv(os.path.join(cems_data_dir_2, file),
                     low_memory=False)
    df_list_2.append(df)

# Concatenate all the dataframes
cems_df_2 = pd.concat(df_list_2, axis=0, ignore_index=True)

# Add time columns from OP_DATE and OP_HOUR
cems_df_2['Time'] = pd.to_datetime(
    cems_df_2['Date']) + pd.to_timedelta(cems_df_2['Operating Time'], unit='h')
# cems_df['Month'] = cems_df['Time'].dt.month

# Drop columns that are not needed
cems_df_2 = cems_df_2.drop(columns=['State', 'Date', 'Hour',
                                    'SO2 Mass Measure Indicator', 'SO2 Rate Measure Indicator',
                                    'CO2 Mass Measure Indicator', 'CO2 Rate Measure Indicator',
                                    'NOx Mass Measure Indicator', 'NOx Rate Measure Indicator',
                                    'Heat Input Measure Indicator', 'Steam Load (1000 lb/hr)', 
                                    'Primary Fuel Type', 'Associated Stacks',
                                    'Secondary Fuel Type', 'Unit Type', 'SO2 Controls', 'NOx Controls',
                                    'PM Controls', 'Hg Controls', 'Program Code'])

# %% [markdown]
# ## Read NYCA CEMS matching table with additional generators

# %%
gen_combiner_2 = pd.read_excel(os.path.join(thermal_data_dir, '2024_nyca_thermal.xlsx'),
                             sheet_name='matched_with_id_filtered')
gen_combiner_2 = gen_combiner_2.rename(columns={
    '   Station        Unit': 'NYISO_Name',
})

# Map unit type GT, JE to CT
gen_combiner_2['Unit Type'] = gen_combiner_2['Unit Type'].replace(
    {'GT': 'CT', 'JE': 'CT'})
gen_combiner_2['Fuel Type Secondary'] = gen_combiner_2['Fuel Type Secondary'].astype(
    str).replace({'nan': ''})

# Only get generators of interest
plant_ids = [56964, 50006, 56940, 57185]
gen_combiner_2 = gen_combiner_2[gen_combiner_2['CAMD_Plant_ID'].isin(plant_ids)]
gen_combiner_2
# Out:
#              NYISO_Name Zone    PTID  Name Plate Rating (MW) Dual Fuel  \
# 134        Linden Cogen    J   23786                   800.0       YES
# 135        Linden Cogen    J   23786                   800.0       YES
# 136        Linden Cogen    J   23786                   800.0       YES
# 137        Linden Cogen    J   23786                   800.0       YES
# 138        Linden Cogen    J   23786                   800.0       YES
# 139        Linden Cogen    J   23786                   800.0       YES
# 203      CPV Valley CC1    G  323721                   385.0       YES
# 204      CPV Valley CC2    G  323722                   385.0       YES
# 205    Bayonne EC  CTG1    J  323682                    64.0       YES
# 206   Bayonne EC  CTG10    J  323750                    64.0       YES
# 207    Bayonne EC  CTG2    J  323683                    64.0       YES
# 208    Bayonne EC  CTG3    J  323684                    64.0       YES
# 209    Bayonne EC  CTG4    J  323685                    64.0       YES
# 210    Bayonne EC  CTG5    J  323686                    64.0       YES
# 211    Bayonne EC  CTG6    J  323687                    64.0       YES
# 212    Bayonne EC  CTG7    J  323688                    64.0       YES
# 213    Bayonne EC  CTG8    J  323689                    64.0       YES
# 214    Bayonne EC  CTG9    J  323749                    64.0       YES
# 215  Cricket Valley CC1    G  323756                   392.3       NaN
# 216  Cricket Valley CC2    G  323757                   392.3       NaN
# 217  Cricket Valley CC3    G  323758                   392.3       NaN
#
#     Unit Type Fuel Type Primary Fuel Type Secondary  2023 Net Energy (GWh)  \
# 134        CC                NG                 BUT                 4390.7
# 135        CC                NG                 BUT                 4390.7
# 136        CC                NG                 BUT                 4390.7
# 137        CC                NG                 BUT                 4390.7
# 138        CC                NG                 BUT                 4390.7
# 139        CC                NG                 BUT                 4390.7
# 203        CC                NG                 FO2                 1322.7
# 204        CC                NG                 FO2                 1312.2
# 205        CT                NG                 KER                  101.8
# 206        CT                NG                 KER                  106.6
# 207        CT                NG                 KER                   76.9
# 208        CT                NG                 KER                   47.0
# 209        CT                NG                 KER                   79.5
# 210        CT                NG                 KER                   38.1
# 211        CT                NG                 KER                   39.5
# 212        CT                NG                 KER                   88.3
# 213        CT                NG                 KER                   72.2
# 214        CT                NG                 KER                  101.8
# 215        CC                NG                                     1799.4
# 216        CC                NG                                     1633.6
# 217        CC                NG                                     1782.1
#
#     Notes  ...            CAMD_Facility_Name CAMD_Plant_ID  CAMD_Unit_ID  \
# 134    NJ  ...  Linden Cogeneration Facility         50006          4001
# 135    NJ  ...  Linden Cogeneration Facility         50006          5001
# 136    NJ  ...  Linden Cogeneration Facility         50006          6001
# 137    NJ  ...  Linden Cogeneration Facility         50006          7001
# 138    NJ  ...  Linden Cogeneration Facility         50006          8001
# 139    NJ  ...  Linden Cogeneration Facility         50006          9001
# 203   NaN  ...          Valley Energy Center         56940             1
# 204   NaN  ...          Valley Energy Center         56940             2
# 205    NJ  ...         Bayonne Energy Center         56964           GT1
# 206    NJ  ...         Bayonne Energy Center         56964          GT10
# 207    NJ  ...         Bayonne Energy Center         56964           GT2
# 208    NJ  ...         Bayonne Energy Center         56964           GT3
# 209    NJ  ...         Bayonne Energy Center         56964           GT4
# 210    NJ  ...         Bayonne Energy Center         56964           GT5
# 211    NJ  ...         Bayonne Energy Center         56964           GT6
# 212    NJ  ...         Bayonne Energy Center         56964           GT7
# 213    NJ  ...         Bayonne Energy Center         56964           GT8
# 214    NJ  ...         Bayonne Energy Center         56964           GT9
# 215   NaN  ...  Cricket Valley Energy Center         57185          U001
# 216   NaN  ...  Cricket Valley Energy Center         57185          U002
# 217   NaN  ...  Cricket Valley Energy Center         57185          U003
#
#     CAMD_Generator_ID CAMD_Nameplate_Capacity        CAMD_Fuel_Type  \
# 134              GTG6                   314.8  Pipeline Natural Gas
# 135              GTG1                   230.8  Pipeline Natural Gas
# 136              GTG2                   230.8  Pipeline Natural Gas
# 137              GTG3                   230.8  Pipeline Natural Gas
# 138              GTG4                   230.8  Pipeline Natural Gas
# 139              GTG5                   230.8  Pipeline Natural Gas
# 203              CTG1                   534.0  Pipeline Natural Gas
# 204              CTG2                   534.0  Pipeline Natural Gas
# 205               GT1                    64.0  Pipeline Natural Gas
# 206              GT10                    64.0  Pipeline Natural Gas
# 207               GT2                    64.0  Pipeline Natural Gas
# 208               GT3                    64.0  Pipeline Natural Gas
# 209               GT4                    64.0  Pipeline Natural Gas
# 210               GT5                    64.0  Pipeline Natural Gas
# 211               GT6                    64.0  Pipeline Natural Gas
# 212               GT7                    64.0  Pipeline Natural Gas
# 213               GT8                    64.0  Pipeline Natural Gas
# 214               GT9                    64.0  Pipeline Natural Gas
# 215               CT1                   410.6  Pipeline Natural Gas
# 216               CT2                   410.6  Pipeline Natural Gas
# 217               CT3                   410.6  Pipeline Natural Gas
#
#     EIA_Latitude  EIA_Longitude            ID eco_min_ratio_obs
# 134    40.632200      -74.21560  (50006,4001)              0.46
# 135    40.632200      -74.21560  (50006,5001)              0.46
# 136    40.632200      -74.21560  (50006,6001)              0.46
# 137    40.632200      -74.21560  (50006,7001)              0.46
# 138    40.632200      -74.21560  (50006,8001)              0.46
# 139    40.632200      -74.21560  (50006,9001)              0.46
# 203    41.412200      -74.43780     (56940,1)              0.50
# 204    41.412200      -74.43780     (56940,2)              0.50
# 205    40.652834      -74.09155   (56964,GT1)              0.50
# 206    40.652834      -74.09155  (56964,GT10)              0.50
# 207    40.652834      -74.09155   (56964,GT2)              0.50
# 208    40.652834      -74.09155   (56964,GT3)              0.50
# 209    40.652834      -74.09155   (56964,GT4)              0.50
# 210    40.652834      -74.09155   (56964,GT5)              0.50
# 211    40.652834      -74.09155   (56964,GT6)              0.50
# 212    40.652834      -74.09155   (56964,GT7)              0.50
# 213    40.652834      -74.09155   (56964,GT8)              0.50
# 214    40.652834      -74.09155   (56964,GT9)              0.50
# 215    41.676200      -73.58060  (57185,U001)              0.48
# 216    41.676200      -73.58060  (57185,U002)              0.48
# 217    41.676200      -73.58060  (57185,U003)              0.48
#
# [21 rows x 21 columns]

# %% [markdown]
# ## Calculate additional generator parameters

# %%
os.makedirs('figures/time_series_2', exist_ok=True)
os.makedirs('figures/heat_rate_2', exist_ok=True)
os.makedirs('figures/nox_rate_2', exist_ok=True)
os.makedirs('figures/co2_rate_2', exist_ok=True)
os.makedirs('figures/so2_rate_2', exist_ok=True)

gen_params_2 = dict()

for ii in tqdm.tqdm(range(gen_combiner_2.shape[0])):
# for ii in tqdm.tqdm(range(1)):
    gen_info = gen_combiner_2.iloc[ii]

    if gen_info['ID'] not in gen_params_2:

        gen_params_2[gen_info['ID']] = dict()

        unit_df = cems_df_2[(cems_df_2['Facility ID'] == gen_info['CAMD_Plant_ID'])
                          & (cems_df_2['Unit ID'] == gen_info['CAMD_Unit_ID'])]
        unit_df = unit_df.set_index('Time').sort_index()
        # print(f'Number of rows: {unit_df.shape[0]}')

        # Calculate hourly ramp
        unit_df['RAMP (MW/hour)'] = unit_df['Gross Load (MW)'].diff()

        # Filter out rows with zero values
        unit_df_nonzero = unit_df[(unit_df['Heat Input (mmBtu)'] > 0) & (
            unit_df['Gross Load (MW)'] > 0)]
        unit_df_nonzero = unit_df_nonzero.drop(columns=['Facility Name',
                                                        'Facility ID', 'Unit ID'])
        # print(f'Number of rows with nonzero values: {unit_df_nonzero.shape[0]}')

        if unit_df_nonzero.shape[0] > 0:

            fig_name_sfx = '_'.join([gen_info["ID"], gen_info["NYISO_Name"],
                                     gen_info["PTID"].astype(str),
                                     gen_info["Unit Type"], gen_info["Fuel Type Primary"],
                                     gen_info["Fuel Type Secondary"]])

            # Time series plot
            df_plot = unit_df[['Operating Time', 'Gross Load (MW)', 'SO2 Mass (lbs)', 'NOx Mass (lbs)',
                               'CO2 Mass (short tons)', 'Heat Input (mmBtu)']]
            fig_ts, ax_ts = plt.subplots(6, 1, figsize=(8, 6), sharex=True,
                                   layout='constrained')
            for i in range(6):
                ax_ts[i].plot(df_plot.iloc[:, i])
                ax_ts[i].set_title(df_plot.columns[i])

            title = (fig_name_sfx + '_' + gen_info["Unit Type"]
                     + '_' + gen_info["Fuel Type Primary"]
                     + '_' + gen_info["Fuel Type Secondary"])
            fig_ts.suptitle(title)
            fig_ts.savefig(f'figures/time_series_2/time_series_{fig_name_sfx}.png')

            # Calculate maximum generation
            max_gen =  unit_df_nonzero['Gross Load (MW)'].max()
            
            # Calculate ramp rate
            raise_rr_ratio = (unit_df_nonzero['RAMP (MW/hour)'].max() / max_gen)
            lower_rr_ratio = np.abs(unit_df_nonzero['RAMP (MW/hour)'].min() / max_gen)
            raise_rr_ratio = raise_rr_ratio if raise_rr_ratio <= 1 else 1
            lower_rr_ratio = lower_rr_ratio if lower_rr_ratio <= 1 else 1
            
            gen_params_2[gen_info['ID']]['NYISO_Name'] = gen_info['NYISO_Name']
            gen_params_2[gen_info['ID']]['PTID'] = gen_info['PTID']
            gen_params_2[gen_info['ID']]['Unit_Type'] = gen_info['Unit Type']
            gen_params_2[gen_info['ID']]['Fuel_Type_Primary'] = gen_info['Fuel Type Primary']
            gen_params_2[gen_info['ID']]['Fuel_Type_Secondary'] = gen_info['Fuel Type Secondary']
            gen_params_2[gen_info['ID']]['CAMD_Facility_Name'] = gen_info['CAMD_Facility_Name']
            gen_params_2[gen_info['ID']]['CAMD_Plant_ID'] = gen_info['CAMD_Plant_ID']
            gen_params_2[gen_info['ID']]['CAMD_Unit_ID'] = gen_info['CAMD_Unit_ID']
            gen_params_2[gen_info['ID']]['CAMD_Nameplate_Capacity'] = gen_info['CAMD_Nameplate_Capacity']
            gen_params_2[gen_info['ID']]['raise_rr_ratio'] = raise_rr_ratio
            gen_params_2[gen_info['ID']]['lower_rr_ratio'] = lower_rr_ratio

            # Heat rate plot
            heat_1, heat_0, heat_r2, eco_min, gen_sum, heat_sum, fig_heat, ax_heat = \
                gp.calc_heat_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='Gross Load (MW)',
                               y_name='Heat Input (mmBtu)',
                               calc_eco_min=False,
                               nonneg_intercept=True,
                               keep_in_range=False)
            gen_params_2[gen_info['ID']]['max_gen'] = max_gen
            gen_params_2[gen_info['ID']]['eco_min'] = eco_min
            gen_params_2[gen_info['ID']]['eco_min_ratio'] = eco_min / max_gen
            gen_params_2[gen_info['ID']]['gen_sum'] = gen_sum
            gen_params_2[gen_info['ID']]['heat_sum'] = heat_sum
            gen_params_2[gen_info['ID']]['heat_1'] = heat_1
            gen_params_2[gen_info['ID']]['heat_0'] = heat_0
            gen_params_2[gen_info['ID']]['heat_r2'] = heat_r2
            if fig_heat is not None:
                fig_heat.savefig(f'figures/heat_rate_2/heat_rate_{fig_name_sfx}.png')

            # NOx emission rate plot
            nox_1, nox_0, nox_r2, nox_avg_rate, nox_sum, fig_nox, ax_nox = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='Heat Input (mmBtu)',
                               y_name='NOx Mass (lbs)',
                               rate_name='NOx Rate (lbs/mmBtu)',
                               gload_name='Gross Load (MW)',
                               heat_input_name='Heat Input (mmBtu)')
            gen_params_2[gen_info['ID']]['nox_1'] = nox_1
            gen_params_2[gen_info['ID']]['nox_0'] = nox_0
            gen_params_2[gen_info['ID']]['nox_r2'] = nox_r2
            gen_params_2[gen_info['ID']]['nox_sum'] = nox_sum
            if fig_nox is not None:
                fig_nox.savefig(f'figures/nox_rate_2/nox_rate_{fig_name_sfx}.png')

            # CO2 emission rate plot
            co2_1, co2_0, co2_r2, co2_avg_rate, co2_sum, fig_co2, ax_co2 = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='Heat Input (mmBtu)',
                               y_name='CO2 Mass (short tons)',
                               rate_name='CO2 Rate (short tons/mmBtu)',
                               gload_name='Gross Load (MW)',
                               heat_input_name='Heat Input (mmBtu)')
            gen_params_2[gen_info['ID']]['co2_1'] = co2_1
            gen_params_2[gen_info['ID']]['co2_0'] = co2_0
            gen_params_2[gen_info['ID']]['co2_r2'] = co2_r2
            gen_params_2[gen_info['ID']]['co2_sum'] = co2_sum
            if fig_co2 is not None:
                fig_co2.savefig(f'figures/co2_rate_2/co2_rate_{fig_name_sfx}.png')

            # SO2 emission rate plot
            so2_1, so2_0, so2_r2, so2_avg_rate, so2_sum, fig_so2, ax_so2 = \
                gp.calc_emis_rate(data=unit_df_nonzero,
                               gen_info=gen_info,
                               x_name='Heat Input (mmBtu)',
                               y_name='SO2 Mass (lbs)',
                               rate_name='SO2 Rate (lbs/mmBtu)',
                               gload_name='Gross Load (MW)',
                               heat_input_name='Heat Input (mmBtu)')
            gen_params_2[gen_info['ID']]['so2_1'] = so2_1
            gen_params_2[gen_info['ID']]['so2_0'] = so2_0
            gen_params_2[gen_info['ID']]['so2_r2'] = so2_r2
            gen_params_2[gen_info['ID']]['so2_sum'] = so2_sum
            if fig_so2 is not None:
                fig_so2.savefig(f'figures/so2_rate_2/so2_rate_{fig_name_sfx}.png')

            plt.close('all')

        else:
            print(f'No data for {fig_name_sfx}.')
            gen_params_2[gen_info['ID']] = None

    else:
        print(f'Data for {gen_info["ID"]} already processed.')
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
# Convert the dictionary to a dataframe
gen_params_df_2 = pd.DataFrame(gen_params_2).T
gen_params_df_2.index.name = 'ID'

# Ramp rate ratio: replace 0 with 1
gen_params_df_2['raise_rr_ratio'] = gen_params_df_2['raise_rr_ratio'].replace({0: 1})
gen_params_df_2['lower_rr_ratio'] = gen_params_df_2['lower_rr_ratio'].replace({0: 1})

# Treatment for bad fit in Astoria GT units
for i, row, in gen_params_df_2[gen_params_df_2['CAMD_Plant_ID']==55243].iterrows():
    default_heat_1 = gp.HEAT_RATE_DEFAULT[row['Unit_Type']][row['Fuel_Type_Primary']]
    row['heat_1'] = default_heat_1
    row['heat_0'] = 0
    row['heat_r2'] = 0
    gen_params_df_2.loc[i] = row

# Treatment fo bad fit in Bethpage CC units
for i, row, in gen_params_df_2[(gen_params_df_2['CAMD_Plant_ID']==50292) & (gen_params_df_2['Unit_Type']=='CC')].iterrows():
    default_heat_1 = gp.HEAT_RATE_DEFAULT[row['Unit_Type']][row['Fuel_Type_Primary']]
    row['heat_1'] = default_heat_1
    row['heat_0'] = 0
    row['heat_r2'] = 0
    gen_params_df_2.loc[i] = row

# %%
# Save to excel
gen_params_df_2.to_excel(os.path.join(thermal_data_dir, 'gen_params_2024.xlsx'))
